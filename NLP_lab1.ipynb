# %%
# !pip install pymorphy3
# Out:
# Requirement already satisfied: pymorphy3 in /usr/local/lib/python3.10/dist-packages (2.0.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy3) (0.7.2)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.10/dist-packages (from pymorphy3) (2.4.417150.4580142)

# %%
import nltk
import pymorphy3
from nltk.tokenize import word_tokenize, sent_tokenize

# Инициализация морфологического анализатора
morph = pymorphy3.MorphAnalyzer()

# Функция для получения леммы и морфологических характеристик
def get_word_info(word):
    parsed_word = morph.parse(word)[0]
    return parsed_word.normal_form, parsed_word.tag

# Функция для проверки совпадений по родам, числам и падежам
def check_gender_number_case(tag1, tag2):
    return tag1.gender == tag2.gender and tag1.number == tag2.number and tag1.case == tag2.case

# Основная функция
def find_noun_adjective_pairs(text):
    # Список для хранения совпавших пар
    matching_pairs = []

    # Токенизация текста на предложения
    sentences = sent_tokenize(text)

    # Проходим по каждому предложению
    for sentence in sentences:
        # Токенизация предложения на слова
        words = word_tokenize(sentence)

        # Пропускаем слишком короткие предложения
        if len(words) < 2:
            continue

        # Для каждой пары соседних слов
        for i in range(len(words) - 1):
            word1, word2 = words[i], words[i + 1]

            # Получаем леммы и грамматические характеристики
            lemma1, tag1 = get_word_info(word1)
            lemma2, tag2 = get_word_info(word2)

            # Вывод отладочной информации
            print(f"Сравниваем пару: {word1} ({lemma1}, {tag1}) - {word2} ({lemma2}, {tag2})")

            # Проверяем, являются ли оба слова существительными или прилагательными
            if ('NOUN' in tag1 or 'ADJF' in tag1) and ('NOUN' in tag2 or 'ADJF' in tag2):
                # Проверяем совпадение по роду, числу и падежу
                if check_gender_number_case(tag1, tag2):
                    print(f"Пара совпадает: {lemma1} {lemma2}")
                    # Добавляем совпавшую пару в список
                    matching_pairs.append((lemma1, lemma2))
                else:
                    print(f"Пара НЕ совпадает по роду, числу и падежу: {lemma1} {lemma2}")

    # Выводим все совпавшие пары
    if matching_pairs:
        print("\nСовпавшие пары (по родам, числам и падежам):")
        for pair in matching_pairs:
            print(f"{pair[0]} {pair[1]}")
    else:
        print("\nСовпавших пар не найдено.")

# Пример текста
text = "В мире существует множество университетов, каждый из которых предлагает уникальные программы обучения. Многие из них имеют богатую историю и традиции. Например, Московский государственный университет, основанный в 1755 году, является одним из самых престижных учебных заведений в России. Он привлекает студентов со всего мира. Университеты часто становятся центрами научных исследований, способствующими развитию новых технологий и идей. Программы для иностранных студентов, обмены и стипендии делают образование доступным для всех. К тому же, в университете студенты могут не только получать знания, но и участвовать в различных культурных и спортивных мероприятиях"

# Вызов функции
find_noun_adjective_pairs(text)
# Out:
# Сравниваем пару: В (в, PREP) - мире (мир, NOUN,inan,masc sing,loct)
# Сравниваем пару: мире (мир, NOUN,inan,masc sing,loct) - существует (существовать, VERB,impf,intr sing,3per,pres,indc)
# Сравниваем пару: существует (существовать, VERB,impf,intr sing,3per,pres,indc) - множество (множество, NOUN,inan,neut sing,nomn)
# Сравниваем пару: множество (множество, NOUN,inan,neut sing,nomn) - университетов (университет, NOUN,inan,masc plur,gent)
# Пара НЕ совпадает по роду, числу и падежу: множество университет
# Сравниваем пару: университетов (университет, NOUN,inan,masc plur,gent) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - каждый (каждый, ADJF,Subx,Apro inan,masc,sing,accs)
# Сравниваем пару: каждый (каждый, ADJF,Subx,Apro inan,masc,sing,accs) - из (из, PREP)
# Сравниваем пару: из (из, PREP) - которых (который, ADJF,Subx,Apro,Anph plur,gent)
# Сравниваем пару: которых (который, ADJF,Subx,Apro,Anph plur,gent) - предлагает (предлагать, VERB,impf,tran sing,3per,pres,indc)
# Сравниваем пару: предлагает (предлагать, VERB,impf,tran sing,3per,pres,indc) - уникальные (уникальный, ADJF,Qual plur,nomn)
# Сравниваем пару: уникальные (уникальный, ADJF,Qual plur,nomn) - программы (программа, NOUN,inan,femn sing,gent)
# Пара НЕ совпадает по роду, числу и падежу: уникальный программа
# Сравниваем пару: программы (программа, NOUN,inan,femn sing,gent) - обучения (обучение, NOUN,inan,neut sing,gent)
# Пара НЕ совпадает по роду, числу и падежу: программа обучение
# Сравниваем пару: обучения (обучение, NOUN,inan,neut sing,gent) - . (., PNCT)
# Сравниваем пару: Многие (многие, NPRO plur,nomn) - из (из, PREP)
# Сравниваем пару: из (из, PREP) - них (они, NPRO,3per,Anph plur,gent,Af-p)
# Сравниваем пару: них (они, NPRO,3per,Anph plur,gent,Af-p) - имеют (иметь, VERB,impf,tran plur,3per,pres,indc)
# Сравниваем пару: имеют (иметь, VERB,impf,tran plur,3per,pres,indc) - богатую (богатый, ADJF,Qual femn,sing,accs)
# Сравниваем пару: богатую (богатый, ADJF,Qual femn,sing,accs) - историю (история, NOUN,inan,femn sing,accs)
# Пара совпадает: богатый история
# Сравниваем пару: историю (история, NOUN,inan,femn sing,accs) - и (и, CONJ)
# Сравниваем пару: и (и, CONJ) - традиции (традиция, NOUN,inan,femn sing,datv)
# Сравниваем пару: традиции (традиция, NOUN,inan,femn sing,datv) - . (., PNCT)
# Сравниваем пару: Например (например, CONJ,Prnt) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - Московский (московский, ADJF masc,sing,nomn)
# Сравниваем пару: Московский (московский, ADJF masc,sing,nomn) - государственный (государственный, ADJF masc,sing,nomn)
# Пара совпадает: московский государственный
# Сравниваем пару: государственный (государственный, ADJF masc,sing,nomn) - университет (университет, NOUN,inan,masc sing,nomn)
# Пара совпадает: государственный университет
# Сравниваем пару: университет (университет, NOUN,inan,masc sing,nomn) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - основанный (основать, PRTF,perf,tran,past,pssv masc,sing,nomn)
# Сравниваем пару: основанный (основать, PRTF,perf,tran,past,pssv masc,sing,nomn) - в (в, PREP)
# Сравниваем пару: в (в, PREP) - 1755 (1755, NUMB,intg)
# Сравниваем пару: 1755 (1755, NUMB,intg) - году (год, NOUN,inan,masc sing,loc2)
# Сравниваем пару: году (год, NOUN,inan,masc sing,loc2) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - является (являться, VERB,impf,intr sing,3per,pres,indc)
# Сравниваем пару: является (являться, VERB,impf,intr sing,3per,pres,indc) - одним (один, ADJF,Apro,Anum masc,sing,ablt)
# Сравниваем пару: одним (один, ADJF,Apro,Anum masc,sing,ablt) - из (из, PREP)
# Сравниваем пару: из (из, PREP) - самых (самый, ADJF,Apro plur,gent)
# Сравниваем пару: самых (самый, ADJF,Apro plur,gent) - престижных (престижный, ADJF,Qual plur,gent)
# Пара совпадает: самый престижный
# Сравниваем пару: престижных (престижный, ADJF,Qual plur,gent) - учебных (учебный, ADJF plur,gent)
# Пара совпадает: престижный учебный
# Сравниваем пару: учебных (учебный, ADJF plur,gent) - заведений (заведение, NOUN,inan,neut plur,gent)
# Пара НЕ совпадает по роду, числу и падежу: учебный заведение
# Сравниваем пару: заведений (заведение, NOUN,inan,neut plur,gent) - в (в, PREP)
# Сравниваем пару: в (в, PREP) - России (россия, NOUN,inan,femn,Sgtm,Geox sing,gent)
# Сравниваем пару: России (россия, NOUN,inan,femn,Sgtm,Geox sing,gent) - . (., PNCT)
# Сравниваем пару: Он (он, NPRO,masc,3per,Anph sing,nomn) - привлекает (привлекать, VERB,impf,tran sing,3per,pres,indc)
# Сравниваем пару: привлекает (привлекать, VERB,impf,tran sing,3per,pres,indc) - студентов (студент, NOUN,anim,masc plur,gent)
# Сравниваем пару: студентов (студент, NOUN,anim,masc plur,gent) - со (с, PREP Vpre)
# Сравниваем пару: со (с, PREP Vpre) - всего (весь, ADJF,Subx,Apro neut,sing,gent)
# Сравниваем пару: всего (весь, ADJF,Subx,Apro neut,sing,gent) - мира (мир, NOUN,inan,masc sing,gent)
# Пара НЕ совпадает по роду, числу и падежу: весь мир
# Сравниваем пару: мира (мир, NOUN,inan,masc sing,gent) - . (., PNCT)
# Сравниваем пару: Университеты (университет, NOUN,inan,masc plur,nomn) - часто (часто, ADVB)
# Сравниваем пару: часто (часто, ADVB) - становятся (становиться, VERB,impf,intr plur,3per,pres,indc)
# Сравниваем пару: становятся (становиться, VERB,impf,intr plur,3per,pres,indc) - центрами (центр, NOUN,inan,masc plur,ablt)
# Сравниваем пару: центрами (центр, NOUN,inan,masc plur,ablt) - научных (научный, ADJF,Qual plur,gent)
# Пара НЕ совпадает по роду, числу и падежу: центр научный
# Сравниваем пару: научных (научный, ADJF,Qual plur,gent) - исследований (исследование, NOUN,inan,neut plur,gent)
# Пара НЕ совпадает по роду, числу и падежу: научный исследование
# Сравниваем пару: исследований (исследование, NOUN,inan,neut plur,gent) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - способствующими (способствовать, PRTF,impf,intr,pres,actv plur,ablt)
# Сравниваем пару: способствующими (способствовать, PRTF,impf,intr,pres,actv plur,ablt) - развитию (развитие, NOUN,inan,neut sing,datv)
# Сравниваем пару: развитию (развитие, NOUN,inan,neut sing,datv) - новых (новый, ADJF,Qual plur,gent)
# Пара НЕ совпадает по роду, числу и падежу: развитие новый
# Сравниваем пару: новых (новый, ADJF,Qual plur,gent) - технологий (технология, NOUN,inan,femn plur,gent)
# Пара НЕ совпадает по роду, числу и падежу: новый технология
# Сравниваем пару: технологий (технология, NOUN,inan,femn plur,gent) - и (и, CONJ)
# Сравниваем пару: и (и, CONJ) - идей (идея, NOUN,inan,femn plur,gent)
# Сравниваем пару: идей (идея, NOUN,inan,femn plur,gent) - . (., PNCT)
# Сравниваем пару: Программы (программа, NOUN,inan,femn sing,gent) - для (для, PREP)
# Сравниваем пару: для (для, PREP) - иностранных (иностранный, ADJF plur,gent)
# Сравниваем пару: иностранных (иностранный, ADJF plur,gent) - студентов (студент, NOUN,anim,masc plur,gent)
# Пара НЕ совпадает по роду, числу и падежу: иностранный студент
# Сравниваем пару: студентов (студент, NOUN,anim,masc plur,gent) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - обмены (обмен, NOUN,inan,masc plur,nomn)
# Сравниваем пару: обмены (обмен, NOUN,inan,masc plur,nomn) - и (и, CONJ)
# Сравниваем пару: и (и, CONJ) - стипендии (стипендия, NOUN,inan,femn plur,nomn)
# Сравниваем пару: стипендии (стипендия, NOUN,inan,femn plur,nomn) - делают (делать, VERB,impf,tran plur,3per,pres,indc)
# Сравниваем пару: делают (делать, VERB,impf,tran plur,3per,pres,indc) - образование (образование, NOUN,inan,neut sing,accs)
# Сравниваем пару: образование (образование, NOUN,inan,neut sing,accs) - доступным (доступный, ADJF,Qual masc,sing,ablt)
# Пара НЕ совпадает по роду, числу и падежу: образование доступный
# Сравниваем пару: доступным (доступный, ADJF,Qual masc,sing,ablt) - для (для, PREP)
# Сравниваем пару: для (для, PREP) - всех (весь, ADJF,Subx,Apro plur,gent)
# Сравниваем пару: всех (весь, ADJF,Subx,Apro plur,gent) - . (., PNCT)
# Сравниваем пару: К (к, PREP) - тому (тот, ADJF,Subx,Apro,Anph neut,sing,datv)
# Сравниваем пару: тому (тот, ADJF,Subx,Apro,Anph neut,sing,datv) - же (же, PRCL)
# Сравниваем пару: же (же, PRCL) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - в (в, PREP)
# Сравниваем пару: в (в, PREP) - университете (университет, NOUN,inan,masc sing,loct)
# Сравниваем пару: университете (университет, NOUN,inan,masc sing,loct) - студенты (студент, NOUN,anim,masc plur,nomn)
# Пара НЕ совпадает по роду, числу и падежу: университет студент
# Сравниваем пару: студенты (студент, NOUN,anim,masc plur,nomn) - могут (мочь, VERB,impf,intr plur,3per,pres,indc)
# Сравниваем пару: могут (мочь, VERB,impf,intr plur,3per,pres,indc) - не (не, PRCL)
# Сравниваем пару: не (не, PRCL) - только (только, ADVB)
# Сравниваем пару: только (только, ADVB) - получать (получать, INFN,impf,tran)
# Сравниваем пару: получать (получать, INFN,impf,tran) - знания (знание, NOUN,inan,neut sing,gent)
# Сравниваем пару: знания (знание, NOUN,inan,neut sing,gent) - , (,, PNCT)
# Сравниваем пару: , (,, PNCT) - но (но, CONJ)
# Сравниваем пару: но (но, CONJ) - и (и, CONJ)
# Сравниваем пару: и (и, CONJ) - участвовать (участвовать, INFN,impf,intr)
# Сравниваем пару: участвовать (участвовать, INFN,impf,intr) - в (в, PREP)
# Сравниваем пару: в (в, PREP) - различных (различный, ADJF,Qual plur,gent)
# Сравниваем пару: различных (различный, ADJF,Qual plur,gent) - культурных (культурный, ADJF,Qual plur,gent)
# Пара совпадает: различный культурный
# Сравниваем пару: культурных (культурный, ADJF,Qual plur,gent) - и (и, CONJ)
# Сравниваем пару: и (и, CONJ) - спортивных (спортивный, ADJF,Qual plur,gent)
# Сравниваем пару: спортивных (спортивный, ADJF,Qual plur,gent) - мероприятиях (мероприятие, NOUN,inan,neut plur,loct)
# Пара НЕ совпадает по роду, числу и падежу: спортивный мероприятие
#
# Совпавшие пары (по родам, числам и падежам):
# богатый история
# московский государственный
# государственный университет
# самый престижный
# престижный учебный
# различный культурный
